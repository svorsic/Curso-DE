# %% [markdown]
# # Vínculo con la API

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
url='https://www.datos.gov.co/resource/er5n-e6tz.json'
df= requests.get(url)
print(df)
# Out:
# <Response [200]>

# %%
print(len(df.text))
df.text
# Out:
# 537799
# '[{"fecha_reporte_web":"2022-01-02 00:00:00","id_de_caso":"5176193","fecha_de_notificaci_n":"2021-12-29 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"Medellin","edad":"15","unidad_medida":"1","sexo":"F","fuente_tipo_contagio":"Relacionado","ubicacion":"Casa","estado":"Leve","recuperado":"Recuperado","fecha_inicio_sintomas":"2021-12-27 00:00:00","fecha_diagnostico":"2021-12-31 00:00:00","fecha_recuperado":"2022-01-10 00:00:00","tipo_recuperacion":"Tiempo","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-02 00:00:00","id_de_caso":"5177076","fecha_de_notificaci_n":"2021-12-29 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"Medellin","edad":"27","unidad_medida":"1","sexo":"M","fuente_tipo_contagio":"Comunitaria","ubicacion":"Casa","estado":"Leve","recuperado":"Recuperado","fecha_inicio_sintomas":"2021-12-27 00:00:00","fecha_diagnostico":"2021-12-31 00:00:00","fecha_recuperado":"2022-01-10 00:00:00","tipo_recuperacion":"Tiempo","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-02 00:00:00","id_de_caso":"5177232","fecha_de_notificaci_n":"2021-12-29 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"Medellin","edad":"41","unidad_medida":"1","sexo":"M","fuente_tipo_contagio":"Relacionado","ubicacion":"Casa","estado":"Leve","recuperado":"Recuperado","fecha_inicio_sintomas":"2021-12-27 00:00:00","fecha_diagnostico":"2021-12-31 00:00:00","fecha_recuperado":"2022-01-10 00:00:00","tipo_recuperacion":"Tiempo","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-25 00:00:00","id_de_caso":"5771116","fecha_de_notificaci_n":"2022-01-24 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"MEDELLIN","edad":"26","unidad_medida":"1","sexo":"F","fuente_tipo_contagio":"Comunitaria","ubicacion":"Casa","estado":"Leve","recuperado":"Recuperado","fecha_inicio_sintomas":"2022-01-20 00:00:00","fecha_diagnostico":"2022-01-24 00:00:00","fecha_recuperado":"2022-01-30 00:00:00","tipo_recuperacion":"Tiempo","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-25 00:00:00","id_de_caso":"5771117","fecha_de_notificaci_n":"2022-01-23 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"MEDELLIN","edad":"25","unidad_medida":"1","sexo":"F","fuente_tipo_contagio":"Relacionado","ubicacion":"Casa","estado":"Leve","recuperado":"Recuperado","fecha_inicio_sintomas":"2022-01-19 00:00:00","fecha_diagnostico":"2022-01-23 00:00:00","fecha_recuperado":"2022-01-29 00:00:00","tipo_recuperacion":"Tiempo","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-25 00:00:00","id_de_caso":"5771733","fecha_de_notificaci_n":"2022-01-22 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"MEDELLIN","edad":"1","unidad_medida":"1","sexo":"F","fuente_tipo_contagio":"Comunitaria","ubicacion":"N/A","estado":"N/A","recuperado":"Recuperado","fecha_inicio_sintomas":"2022-01-19 00:00:00","fecha_muerte":"2023-01-10 00:00:00","fecha_diagnostico":"2022-01-23 00:00:00","fecha_recuperado":"2022-01-29 00:00:00","tipo_recuperacion":"PCR","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-03 00:00:00","id_de_caso":"5187769","fecha_de_notificaci_n":"2021-12-31 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciudad_municipio_nom":"MEDELLIN","edad":"22","unidad_medida":"1","sexo":"F","fuente_tipo_contagio":"Comunitaria","ubicacion":"Casa","estado":"Leve","recuperado":"Recuperado","fecha_inicio_sintomas":"2021-12-26 00:00:00","fecha_diagnostico":"2021-12-31 00:00:00","fecha_recuperado":"2022-01-09 00:00:00","tipo_recuperacion":"Tiempo","per_etn_":"6"}\n,{"fecha_reporte_web":"2022-01-03 00:00:00","id_de_caso":"5187779","fecha_de_notificaci_n":"2021-12-31 00:00:00","departamento":"5","departamento_nom":"ANTIOQUIA","ciudad_municipio":"5001","ciuda ...

# %%
texto=df.text
json.loads(texto)
# Out:
# [{'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176193',
#   'fecha_de_notificaci_n': '2021-12-29 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'Medellin',
#   'edad': '15',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5177076',
#   'fecha_de_notificaci_n': '2021-12-29 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'Medellin',
#   'edad': '27',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5177232',
#   'fecha_de_notificaci_n': '2021-12-29 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'Medellin',
#   'edad': '41',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-25 00:00:00',
#   'id_de_caso': '5771116',
#   'fecha_de_notificaci_n': '2022-01-24 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '26',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2022-01-20 00:00:00',
#   'fecha_diagnostico': '2022-01-24 00:00:00',
#   'fecha_recuperado': '2022-01-30 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-25 00:00:00',
#   'id_de_caso': '5771117',
#   'fecha_de_notificaci_n': '2022-01-23 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '25',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2022-01-19 00:00:00',
#   'fecha_diagnostico': '2022-01-23 00:00:00',
#   'fecha_recuperado': '2022-01-29 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-25 00:00:00',
#   'id_de_caso': '5771733',
#   'fecha_de_notificaci_n': '2022-01-22 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '1',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'N/A',
#   'estado': 'N/A',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2022-01-19 00:00:00',
#   'fecha_muerte': '2023-01-10 00:00:00',
#   'fecha_diagnostico': '2022-01-23 00:00:00',
#   'fecha_recuperado': '2022-01-29 00:00:00',
#   'tipo_recuperacion': 'PCR',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187769',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '22',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-26 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-09 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187779',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '30',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187787',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '1',
#   'unidad_medida': '2',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187788',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '26',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5188142',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '20',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5188150',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '25',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187626',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '47',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187628',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '71',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187629',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '43',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187631',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '70',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187632',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '69',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187633',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '69',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '5'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187634',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '67',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187635',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '64',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187636',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '64',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187637',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '64',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187638',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '65',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187639',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '66',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-19 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187640',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '64',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187641',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '66',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187642',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '64',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187643',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '66',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187644',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '65',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187645',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '63',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '5'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187646',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '63',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187647',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '60',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187648',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '59',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187649',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '58',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187650',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '63',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187651',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '60',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187652',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '60',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'PCR',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187653',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '60',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187654',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '57',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '5'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187655',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '50',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187656',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '55',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Fallecido',
#   'estado': 'Fallecido',
#   'recuperado': 'Fallecido',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_muerte': '2022-01-12 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187657',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '42',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187658',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '42',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187659',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '41',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'PCR',
#   'per_etn_': '5'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187660',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '39',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187661',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '38',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187662',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '40',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187663',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '39',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187664',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '41',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187665',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '42',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187666',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '43',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187667',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '42',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187668',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '38',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187669',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '40',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187670',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '40',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187671',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '48',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187672',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '56',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187673',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '37',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187674',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '62',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187675',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '64',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187676',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '61',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'PCR',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187678',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '61',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187679',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '60',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187680',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '61',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187682',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '55',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187684',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '50',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187685',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '50',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187687',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '50',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187688',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '49',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187689',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '49',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187690',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '47',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187691',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '47',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187692',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '47',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187693',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '45',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187694',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '45',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187695',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '43',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187696',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '44',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187697',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '45',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-28 00:00:00',
#   'fecha_diagnostico': '2022-01-01 00:00:00',
#   'fecha_recuperado': '2022-01-11 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-03 00:00:00',
#   'id_de_caso': '5187698',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '43',
# ...
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176278',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '28',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176279',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '27',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176282',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '25',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176283',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '25',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176288',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '22',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176293',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '32',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176295',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '27',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176296',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '26',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176298',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '29',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176301',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '23',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176303',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '30',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176307',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '23',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176310',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '33',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176316',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '23',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176319',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '30',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '5'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176321',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '29',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176326',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '30',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176327',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '30',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176328',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '26',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176331',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '29',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176349',
#   'fecha_de_notificaci_n': '2021-12-30 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '23',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176350',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '34',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176352',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '33',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Relacionado',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176353',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '31',
#   'unidad_medida': '1',
#   'sexo': 'F',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-02 00:00:00',
#   'id_de_caso': '5176354',
#   'fecha_de_notificaci_n': '2021-12-31 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '1',
#   'unidad_medida': '2',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-27 00:00:00',
#   'fecha_diagnostico': '2021-12-31 00:00:00',
#   'fecha_recuperado': '2022-01-10 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'},
#  {'fecha_reporte_web': '2022-01-01 00:00:00',
#   'id_de_caso': '5158831',
#   'fecha_de_notificaci_n': '2021-12-28 00:00:00',
#   'departamento': '5',
#   'departamento_nom': 'ANTIOQUIA',
#   'ciudad_municipio': '5001',
#   'ciudad_municipio_nom': 'MEDELLIN',
#   'edad': '21',
#   'unidad_medida': '1',
#   'sexo': 'M',
#   'fuente_tipo_contagio': 'Comunitaria',
#   'ubicacion': 'Casa',
#   'estado': 'Leve',
#   'recuperado': 'Recuperado',
#   'fecha_inicio_sintomas': '2021-12-25 00:00:00',
#   'fecha_diagnostico': '2021-12-29 00:00:00',
#   'fecha_recuperado': '2022-01-08 00:00:00',
#   'tipo_recuperacion': 'Tiempo',
#   'per_etn_': '6'}]

# %%
jsondata=json.loads(texto)
dfCol=pd.DataFrame.from_dict(jsondata)
dfCol
# Out:
#        fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento
# 0    2022-01-02 00:00:00    5176193   2021-12-29 00:00:00            5  \
# 1    2022-01-02 00:00:00    5177076   2021-12-29 00:00:00            5
# 2    2022-01-02 00:00:00    5177232   2021-12-29 00:00:00            5
# 3    2022-01-25 00:00:00    5771116   2022-01-24 00:00:00            5
# 4    2022-01-25 00:00:00    5771117   2022-01-23 00:00:00            5
# ..                   ...        ...                   ...          ...
# 995  2022-01-02 00:00:00    5176350   2021-12-31 00:00:00            5
# 996  2022-01-02 00:00:00    5176352   2021-12-31 00:00:00            5
# 997  2022-01-02 00:00:00    5176353   2021-12-31 00:00:00            5
# 998  2022-01-02 00:00:00    5176354   2021-12-31 00:00:00            5
# 999  2022-01-01 00:00:00    5158831   2021-12-28 00:00:00            5
#
#     departamento_nom ciudad_municipio ciudad_municipio_nom edad unidad_medida
# 0          ANTIOQUIA             5001             Medellin   15             1  \
# 1          ANTIOQUIA             5001             Medellin   27             1
# 2          ANTIOQUIA             5001             Medellin   41             1
# 3          ANTIOQUIA             5001             MEDELLIN   26             1
# 4          ANTIOQUIA             5001             MEDELLIN   25             1
# ..               ...              ...                  ...  ...           ...
# 995        ANTIOQUIA             5001             MEDELLIN   34             1
# 996        ANTIOQUIA             5001             MEDELLIN   33             1
# 997        ANTIOQUIA             5001             MEDELLIN   31             1
# 998        ANTIOQUIA             5001             MEDELLIN    1             2
# 999        ANTIOQUIA             5001             MEDELLIN   21             1
#
#     sexo  ... ubicacion estado  recuperado fecha_inicio_sintomas
# 0      F  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00  \
# 1      M  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00
# 2      M  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00
# 3      F  ...      Casa   Leve  Recuperado   2022-01-20 00:00:00
# 4      F  ...      Casa   Leve  Recuperado   2022-01-19 00:00:00
# ..   ...  ...       ...    ...         ...                   ...
# 995    M  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00
# 996    F  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00
# 997    F  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00
# 998    M  ...      Casa   Leve  Recuperado   2021-12-27 00:00:00
# 999    M  ...      Casa   Leve  Recuperado   2021-12-25 00:00:00
#
#        fecha_diagnostico     fecha_recuperado tipo_recuperacion per_etn_
# 0    2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6  \
# 1    2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6
# 2    2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6
# 3    2022-01-24 00:00:00  2022-01-30 00:00:00            Tiempo        6
# 4    2022-01-23 00:00:00  2022-01-29 00:00:00            Tiempo        6
# ..                   ...                  ...               ...      ...
# 995  2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6
# 996  2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6
# 997  2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6
# 998  2021-12-31 00:00:00  2022-01-10 00:00:00            Tiempo        6
# 999  2021-12-29 00:00:00  2022-01-08 00:00:00            Tiempo        6
#
#     fecha_muerte nom_grupo_
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ..           ...        ...
# 995          NaN        NaN
# 996          NaN        NaN
# 997          NaN        NaN
# 998          NaN        NaN
# 999          NaN        NaN
#
# [1000 rows x 21 columns]

# %%
type(jsondata)
# Out:
# list

# %%
dfCol.shape
# Out:
# (1000, 21)

# %%
dfCol.describe()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento
# count                  1000       1000                  1000         1000  \
# unique                    4       1000                    17            1
# top     2022-01-01 00:00:00    5176193   2021-12-31 00:00:00            5
# freq                    478          1                   369         1000
#
#        departamento_nom ciudad_municipio ciudad_municipio_nom  edad
# count              1000             1000                 1000  1000  \
# unique                1                1                    2    84
# top           ANTIOQUIA             5001             MEDELLIN    20
# freq               1000             1000                  997    41
#
#        unidad_medida  sexo  ... ubicacion estado  recuperado
# count           1000  1000  ...      1000   1000        1000  \
# unique             2     2  ...         3      3           3
# top                1     F  ...      Casa   Leve  Recuperado
# freq             998   635  ...       992    992         994
#
#        fecha_inicio_sintomas    fecha_diagnostico     fecha_recuperado
# count                   1000                 1000                  994  \
# unique                    21                   15                   18
# top      2021-12-27 00:00:00  2021-12-31 00:00:00  2022-01-10 00:00:00
# freq                     273                  290                  271
#
#        tipo_recuperacion per_etn_         fecha_muerte     nom_grupo_
# count                994     1000                    8              1
# unique                 2        3                    8              1
# top               Tiempo        6  2023-01-10 00:00:00  Sin Comunidad
# freq                 963      975                    1              1
#
# [4 rows x 21 columns]

# %% [markdown]
# ## Visualizaciones rápidas acerca de los datos

# %%
IniSin = dfCol.fecha_inicio_sintomas.value_counts()
IniSin.plot(figsize=(15,8), title='Fecha de inicio de síntomas')
# Out:
# <Axes: title={'center': 'Fecha de inicio de síntomas'}, xlabel='fecha_inicio_sintomas'>

# %%
Se = dfCol.sexo.value_counts()
fig,ax = plt.subplots(figsize =(15, 8))
ax.pie(Se, labels = Se.index,autopct='%1.1f%%')
ax.set_title("Distribución por sexo")
# Out:
# Text(0.5, 1.0, 'Distribución por sexo')

# %%
Edad = dfCol.edad.value_counts()
fig,ax = plt.subplots(figsize =(15, 8))
ax.bar(Edad.index, Edad)
ax.set_title("Edades de afectados")
ax.set_xlabel('Edades')
ax.set_ylabel('Cantidad de pacientes')
# Out:
# Text(0, 0.5, 'Cantidad de pacientes')

# %% [markdown]
# #Transformación de los datos con librería Pandas

# %% [markdown]
# #### Se analizan los datos de la base. Se busca identificar si se requiere limpiar o adecuar algún dato, o líneas duplicadas.

# %%
dfCol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_reporte_web      1000 non-null   object
#  1   id_de_caso             1000 non-null   object
#  2   fecha_de_notificaci_n  1000 non-null   object
#  3   departamento           1000 non-null   object
#  4   departamento_nom       1000 non-null   object
#  5   ciudad_municipio       1000 non-null   object
#  6   ciudad_municipio_nom   1000 non-null   object
#  7   edad                   1000 non-null   object
#  8   unidad_medida          1000 non-null   object
#  9   sexo                   1000 non-null   object
#  10  fuente_tipo_contagio   1000 non-null   object
#  11  ubicacion              1000 non-null   object
#  12  estado                 1000 non-null   object
#  13  recuperado             1000 non-null   object
#  14  fecha_inicio_sintomas  1000 non-null   object
#  15  fecha_diagnostico      1000 non-null   object
#  16  fecha_recuperado       994 non-null    object
#  17  tipo_recuperacion      994 non-null    object
#  18  per_etn_               1000 non-null   object
#  19  fecha_muerte           8 non-null      object
#  20  nom_grupo_             1 non-null      object
# dtypes: object(21)
# memory usage: 164.2+ KB

# %% [markdown]
# ### **Borrado de duplicados**

# %%
dfCol.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
dfCol.drop_duplicates()
print(dfCol.shape)
# Out:
# (1000, 21)

# %% [markdown]
# #### La base no presenta datos duplicados, por tanto se procede a trabajar sobre los datos nulos.

# %% [markdown]
# ### **Análisis de nulos**

# %%
pd.set_option('display.max_rows', None)
serie=(dfCol.isnull().sum()/dfCol.shape[0])*100
serie=serie.sort_values(ascending=False)
serie= serie[serie>0]
serie
# Out:
# nom_grupo_           99.9
# fecha_muerte         99.2
# tipo_recuperacion     0.6
# fecha_recuperado      0.6
# dtype: float64

# %% [markdown]
# #### Se identifican dos columnas que presentan datos nulos y se analiza el porcentaje del impacto de los datos nulos sobre esos valores.
# #### A continuación se procede con análisis gráficos para tener una referencia más concreta de los anteriores valores numéricos.

# %%
plt.figure(figsize=(10,6))
serie.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### Análisis de nulos con la herramienta Missingino

# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from missingno) (1.23.5)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from missingno) (1.10.1)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.10/site-packages (from seaborn->missingno) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno
msno.matrix(dfCol)
# Out:
# <Axes: >

# %%
msno.heatmap(dfCol)
# Out:
# <Axes: >

# %%
msno.dendrogram(dfCol)
# Out:
# <Axes: >

# %% [markdown]
# ### **Análisis de las variables con datos nulos**
#
# #### Se exploran los datos y su variedad dentro de las columnas que presentan datos nulos para determinar una acción a tomar con las mismas. Se pude notar que una de las principales causantes de los datos nulos es la diferencia entre fallecidos y no fallecidos. Este es un dato relevante, por tanto, se evaluará la manera de que se pueda mantener la distinción sin perjudicar la integridad de la base.

# %%
dfCol.estado.value_counts()
# Out:
# estado
# Leve         992
# N/A            4
# Fallecido      4
# Name: count, dtype: int64

# %% [markdown]
# #### La columna estado indica con claridad la distinción, por tanto, puede procederse a intervenir las columnas con datos nulos.

# %%
dfCol.fecha_muerte.value_counts()
# Out:
# fecha_muerte
# 2023-01-10 00:00:00    1
# 2022-01-12 00:00:00    1
# 2022-01-04 00:00:00    1
# 2023-05-14 00:00:00    1
# 2022-01-26 00:00:00    1
# 2023-05-24 00:00:00    1
# 2022-02-04 00:00:00    1
# 2022-01-17 00:00:00    1
# Name: count, dtype: int64

# %% [markdown]
# #### La columna fecha_muerte presenta demasiados valores nulos. Esto se debe a que la gran mayoría de los pacientes se ha recuperdado. La fecha resulta relevante para hacer estudios posteriores. Por tanto, se intentará conservar la columna para análisis posteriores. Los datos nulos serán reemplazados por N/A (No aplica).

# %%
dfCol.fecha_recuperado.value_counts()
# Out:
# fecha_recuperado
# 2022-01-10 00:00:00    271
# 2022-01-09 00:00:00    253
# 2022-01-07 00:00:00    201
# 2022-01-11 00:00:00    186
# 2022-01-29 00:00:00     26
# 2022-01-30 00:00:00     14
# 2022-01-12 00:00:00     10
# 2022-01-26 00:00:00      7
# 2022-01-28 00:00:00      6
# 2022-01-13 00:00:00      5
# 2022-01-02 00:00:00      4
# 2022-01-08 00:00:00      4
# 2022-01-04 00:00:00      2
# 2022-01-05 00:00:00      1
# 2022-01-19 00:00:00      1
# 2022-01-15 00:00:00      1
# 2022-01-03 00:00:00      1
# 2021-12-20 00:00:00      1
# Name: count, dtype: int64

# %% [markdown]
# #### La columna fecha_recuperado tiene un pequeño número de datos nulos. Lo ideal sería poder conservar la información aplicando algún método de sustitución. Los datos nulos serán reemplazados por N/A.

# %%
dfCol.tipo_recuperacion.value_counts()
# Out:
# tipo_recuperacion
# Tiempo    963
# PCR        31
# Name: count, dtype: int64

# %% [markdown]
# #### La columna tipo_recuperacion podría ser relevante para posteriores estudios. Se decide sustituir los valores nulos por N/A.

# %%
dfCol.nom_grupo_.value_counts()
# Out:
# nom_grupo_
# Sin Comunidad    1
# Name: count, dtype: int64

# %% [markdown]
# La columna Nom_grupo_ no presenta una distinción de relevancia para el estudio, por tanto se decide borrarla.

# %%
# eliminacón de columna nom_grupo_
col_del=['nom_grupo_']
dfCol_2=dfCol.drop(labels=col_del, axis=1)
dfCol_2.columns
# Out:
# Index(['fecha_reporte_web', 'id_de_caso', 'fecha_de_notificaci_n',
#        'departamento', 'departamento_nom', 'ciudad_municipio',
#        'ciudad_municipio_nom', 'edad', 'unidad_medida', 'sexo',
#        'fuente_tipo_contagio', 'ubicacion', 'estado', 'recuperado',
#        'fecha_inicio_sintomas', 'fecha_diagnostico', 'fecha_recuperado',
#        'tipo_recuperacion', 'per_etn_', 'fecha_muerte'],
#       dtype='object')

# %%
# Sustitución de valores en las restantes columnas a preservar.
col_sus= ['fecha_muerte','fecha_recuperado','tipo_recuperacion']
for i in col_sus:
  dfCol_2[i] = dfCol_2[i].fillna('N/A')

# %% [markdown]
# ## Verificando que no hay datos nulos

# %%
dfCol_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_reporte_web      1000 non-null   object
#  1   id_de_caso             1000 non-null   object
#  2   fecha_de_notificaci_n  1000 non-null   object
#  3   departamento           1000 non-null   object
#  4   departamento_nom       1000 non-null   object
#  5   ciudad_municipio       1000 non-null   object
#  6   ciudad_municipio_nom   1000 non-null   object
#  7   edad                   1000 non-null   object
#  8   unidad_medida          1000 non-null   object
#  9   sexo                   1000 non-null   object
#  10  fuente_tipo_contagio   1000 non-null   object
#  11  ubicacion              1000 non-null   object
#  12  estado                 1000 non-null   object
#  13  recuperado             1000 non-null   object
#  14  fecha_inicio_sintomas  1000 non-null   object
#  15  fecha_diagnostico      1000 non-null   object
#  16  fecha_recuperado       1000 non-null   object
#  17  tipo_recuperacion      1000 non-null   object
#  18  per_etn_               1000 non-null   object
#  19  fecha_muerte           1000 non-null   object
# dtypes: object(20)
# memory usage: 156.4+ KB

# %% [markdown]
# No se presentan datos nulos, el proceso ha sido exitoso.

# %% [markdown]
# ## Ajuste de tipos de datos

# %%
dfCol_2['id_de_caso'] = dfCol_2['id_de_caso'].astype('int')
dfCol_2['departamento'] = dfCol_2['departamento'].astype('int')
dfCol_2['edad'] = dfCol_2['edad'].astype('int')
dfCol_2['per_etn_'] = dfCol_2['per_etn_'].astype('int')
dfCol_2['ciudad_municipio'] = dfCol_2['ciudad_municipio'].astype('int')

# %%
dfCol_2['fecha_reporte_web'] = dfCol_2['fecha_reporte_web'].astype('datetime64[ns]')
dfCol_2['fecha_de_notificaci_n'] = dfCol_2['fecha_de_notificaci_n'].astype('datetime64[ns]')
dfCol_2['fecha_inicio_sintomas'] = dfCol_2['fecha_inicio_sintomas'].astype('datetime64[ns]')
dfCol_2['fecha_diagnostico'] = dfCol_2['fecha_diagnostico'].astype('datetime64[ns]')

# %% [markdown]
# #### Verificación de cambios

# %%
dfCol_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_reporte_web      1000 non-null   datetime64[ns]
#  1   id_de_caso             1000 non-null   int64
#  2   fecha_de_notificaci_n  1000 non-null   datetime64[ns]
#  3   departamento           1000 non-null   int64
#  4   departamento_nom       1000 non-null   object
#  5   ciudad_municipio       1000 non-null   int64
#  6   ciudad_municipio_nom   1000 non-null   object
#  7   edad                   1000 non-null   int64
#  8   unidad_medida          1000 non-null   object
#  9   sexo                   1000 non-null   object
#  10  fuente_tipo_contagio   1000 non-null   object
#  11  ubicacion              1000 non-null   object
#  12  estado                 1000 non-null   object
#  13  recuperado             1000 non-null   object
#  14  fecha_inicio_sintomas  1000 non-null   datetime64[ns]
#  15  fecha_diagnostico      1000 non-null   datetime64[ns]
#  16  fecha_recuperado       1000 non-null   object
#  17  tipo_recuperacion      1000 non-null   object
#  18  per_etn_               1000 non-null   int64
#  19  fecha_muerte           1000 non-null   object
# dtypes: datetime64[ns](4), int64(5), object(11)
# memory usage: 156.4+ KB

# %% [markdown]
# ## Limpieza de valores redundantes
#
# #### Referencias al municipio y al departamente son redundantes, ya que todos los datos pertenecen al mismo departamento y al mismo municipio, es decir, departamento de Antioquia, municipio de Medellin en Colombia.

# %%
dfCol_2.ciudad_municipio_nom.value_counts()
# Out:
# ciudad_municipio_nom
# MEDELLIN    997
# Medellin      3
# Name: count, dtype: int64

# %%
dfCol_2.departamento_nom.value_counts()
# Out:
# departamento_nom
# ANTIOQUIA    1000
# Name: count, dtype: int64

# %%
col_Ant=['departamento_nom', 'ciudad_municipio_nom']
dfCol_3=dfCol_2.drop(labels=col_Ant, axis=1)
dfCol_3.columns
# Out:
# Index(['fecha_reporte_web', 'id_de_caso', 'fecha_de_notificaci_n',
#        'departamento', 'ciudad_municipio', 'edad', 'unidad_medida', 'sexo',
#        'fuente_tipo_contagio', 'ubicacion', 'estado', 'recuperado',
#        'fecha_inicio_sintomas', 'fecha_diagnostico', 'fecha_recuperado',
#        'tipo_recuperacion', 'per_etn_', 'fecha_muerte'],
#       dtype='object')

# %% [markdown]
# ## Recodificar variables categoricas

# %%
alldata=[]
alldata1=[]
variables=[]
for i in dfCol_3.columns:
  if dfCol_3[i].dtype == 'O':
    if len(dfCol_3[i].unique()) ==2:
      print('Variable 2 categorias:',i)
      y= pd.get_dummies(dfCol_3[i])
      alldata.append(y)
      variables.append(i)
    else:
      pass
    print('--------------------')
    if len(dfCol_3[i].unique()) >2:
      print('Variable >2 categorias:',i)
      z= pd.DataFrame()
      z[i]=dfCol_3[i].astype('category').cat.codes
      alldata1.append(z)
      variables.append(i)
  if dfCol_3[i].dtype == 'float64':
    dfCol_3[i]=(dfCol_3[i]-dfCol_3[i].mean())/(dfCol_3[i].std())
data_y=pd.concat(alldata, axis=1)
data_z=pd.concat(alldata1, axis=1)
dfCol_Ok= pd.concat([data_y,data_z,dfCol_3],axis=1)
dfCol_Ok=dfCol_Ok.drop(labels=variables, axis=1)
dfCol_Ok.head() # mostrar que quedo
# Out:
# Variable 2 categorias: unidad_medida
# --------------------
# Variable 2 categorias: sexo
# --------------------
# Variable 2 categorias: fuente_tipo_contagio
# --------------------
# --------------------
# Variable >2 categorias: ubicacion
# --------------------
# Variable >2 categorias: estado
# --------------------
# Variable >2 categorias: recuperado
# --------------------
# Variable >2 categorias: fecha_recuperado
# --------------------
# Variable >2 categorias: tipo_recuperacion
# --------------------
# Variable >2 categorias: fecha_muerte
#       1      2      F      M  Comunitaria  Relacionado fecha_reporte_web
# 0  True  False   True  False        False         True        2022-01-02  \
# 1  True  False  False   True         True        False        2022-01-02
# 2  True  False  False   True        False         True        2022-01-02
# 3  True  False   True  False         True        False        2022-01-25
# 4  True  False   True  False        False         True        2022-01-25
#
#    id_de_caso fecha_de_notificaci_n  departamento  ciudad_municipio  edad
# 0     5176193            2021-12-29             5              5001    15  \
# 1     5177076            2021-12-29             5              5001    27
# 2     5177232            2021-12-29             5              5001    41
# 3     5771116            2022-01-24             5              5001    26
# 4     5771117            2022-01-23             5              5001    25
#
#   fecha_inicio_sintomas fecha_diagnostico  per_etn_
# 0            2021-12-27        2021-12-31         6
# 1            2021-12-27        2021-12-31         6
# 2            2021-12-27        2021-12-31         6
# 3            2022-01-20        2022-01-24         6
# 4            2022-01-19        2022-01-23         6

# %% [markdown]
# ## Resultado del proceso de transformación de los datos

# %%
dfCol_Ok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   1                      1000 non-null   bool
#  1   2                      1000 non-null   bool
#  2   F                      1000 non-null   bool
#  3   M                      1000 non-null   bool
#  4   Comunitaria            1000 non-null   bool
#  5   Relacionado            1000 non-null   bool
#  6   fecha_reporte_web      1000 non-null   datetime64[ns]
#  7   id_de_caso             1000 non-null   int64
#  8   fecha_de_notificaci_n  1000 non-null   datetime64[ns]
#  9   departamento           1000 non-null   int64
#  10  ciudad_municipio       1000 non-null   int64
#  11  edad                   1000 non-null   int64
#  12  fecha_inicio_sintomas  1000 non-null   datetime64[ns]
#  13  fecha_diagnostico      1000 non-null   datetime64[ns]
#  14  per_etn_               1000 non-null   int64
# dtypes: bool(6), datetime64[ns](4), int64(5)
# memory usage: 76.3 KB

# %% [markdown]
# # Cargar datos en la tabla de Redshift

# %%
pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 5.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# Crear sesion de Spark

import os
import psycopg2

from pyspark.sql import SparkSession
from pyspark.sql.functions import when, lit, col

# Postgres and Redshift JDBCs
driver_path = "/home/working_dir/Entregables/driver_jdbc/postgresql-42.2.27.jre7.jar"

os.environ['PYSPARK_SUBMIT_ARGS'] = f'--driver-class-path {driver_path} --jars {driver_path} pyspark-shell'
os.environ['SPARK_CLASSPATH'] = driver_path

# Create SparkSession
spark = SparkSession.builder \
        .master("local") \
        .appName("Conexion entre Pyspark y Redshift") \
        .config("spark.jars", driver_path) \
        .config("spark.executor.extraClassPath", driver_path) \
        .getOrCreate()

# %%
env = os.environ

# %%
# Connect to Redshift using psycopg2
conn = psycopg2.connect(
    host=env['AWS_REDSHIFT_HOST'],
    port=env['AWS_REDSHIFT_PORT'],
    dbname=env['AWS_REDSHIFT_DBNAME'],
    user=env['AWS_REDSHIFT_USER'],
    password=env['AWS_REDSHIFT_PASSWORD']
)

# %%
cursor = conn.cursor()
cursor.execute(f"""
create table if not exists {env['AWS_REDSHIFT_SCHEMA']}.dfCol (
    "1" INT,
    "2" INT,
    "F" INT,
    "M" INT,
    "Comunitaria" INT,
    "Relacionado" INT,
    "fecha_reporte_web" DATETIME,
    "id_de_caso" INT distkey,
    "fecha_de_notificaci_n" DATETIME,
    "departamento" INT,
    "ciudad_municipio" INT,
    "edad" INT,
    "fecha_inicio_sintomas" DATETIME,
    "fecha_diagnostico" DATETIME,
    "per_etn_" INT
) sortkey(id_de_caso);
""")
conn.commit()
cursor.close()
print("Table created!")
# Out:
# Table created!

# %%
cursor = conn.cursor()
cursor.execute(f"""
SELECT
  distinct tablename
FROM
  PG_TABLE_DEF
WHERE
  schemaname = '{env['AWS_REDSHIFT_SCHEMA']}';
""")
# resultado = cursor.fetchall()
print(", ".join(map(lambda x: x[0], cursor.fetchall())))
cursor.close()
# Out:
# dfcol

# %%
# Create the DataFrame with the specified column names
dfCol3 = spark.createDataFrame(dfCol_Ok['data'], ["1", "2", "F", "M", "Comunitaria", "Relacionado", "fecha_reporte_web", "id_de_caso", "fecha_de_notificaci_n", "departamento", "ciudad_municipio", "edad", "fecha_inicio_sintomas", "fecha_diagnostico", "per_etn_" ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Create the DataFrame with the specified column names
# ----> 2 dfCol3 = spark.createDataFrame(dfCol_Ok['data'], ["1", "2", "F", "M", "Comunitaria", "Relacionado", "fecha_reporte_web", "id_de_caso", "fecha_de_notificaci_n", "departamento", "ciudad_municipio", "edad", "fecha_inicio_sintomas", "fecha_diagnostico", "per_etn_" ])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'data'

# %%
dfCol3.printSchema()
dfCol3.show()

# %%
dfCol_to_write = dfCol3.withColumn('frequency', lit('Mensual'))
dfCol_to_write.printSchema()
dfCol_to_write.show()

# %%
dfCol_to_write.write \
    .format("jdbc") \
    .option("url", f"jdbc:postgresql://{env['AWS_REDSHIFT_HOST']}:{env['AWS_REDSHIFT_PORT']}/{env['AWS_REDSHIFT_DBNAME']}") \
    .option("dbtable", f"{env['AWS_REDSHIFT_SCHEMA']}.exportaciones_cereales") \
    .option("user", env['AWS_REDSHIFT_USER']) \
    .option("password", env['AWS_REDSHIFT_PASSWORD']) \
    .option("driver", "org.postgresql.Driver") \
    .mode("overwrite") \
    .save()

# %%
# Query Redshift using Spark SQL
query = f"select * from {env['AWS_REDSHIFT_SCHEMA']}.dfCol"
data = spark.read \
    .format("jdbc") \
    .option("url", f"jdbc:postgresql://{env['AWS_REDSHIFT_HOST']}:{env['AWS_REDSHIFT_PORT']}/{env['AWS_REDSHIFT_DBNAME']}") \
    .option("dbtable", f"({query}) as tmp_table") \
    .option("user", env['AWS_REDSHIFT_USER']) \
    .option("password", env['AWS_REDSHIFT_PASSWORD']) \
    .option("driver", "org.postgresql.Driver") \
    .load()

# %%
data.printSchema()
data.show()

# %%
conn.close()
